# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### Question 1

# %%
A = [1,2,3,4,5,6]

# %%
B = [13, 21, 34]

# %%
A_B = A + B

# %%
A_B
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %% [markdown]
# ### Question 2

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
data_set = pd.read_csv('Quiz_Data.csv')

# %%
data_set.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
data_set
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %% [markdown]
# ### Question 3

# %%
fuel_type_group = data_set.groupby('fuel_type_code_pudl')

# %%
fuel_type_group.describe()
# Out:
#                     utility_id_ferc1                                     \
#                                count        mean        std  min    25%
# fuel_type_code_pudl
# coal                          8547.0  115.637534  72.859332  1.0   51.0
# gas                          11486.0  124.122062  73.743929  1.0   56.0
# nuclear                        818.0  107.397311  78.973446  2.0   39.0
# oil                           8064.0  113.236235  75.998379  1.0   45.0
# other                          167.0  110.467066  47.145735  2.0   89.0
# waste                          441.0  154.253968  53.367073  9.0  121.0
#
#                                          report_year               ...  \
#                        50%    75%    max       count         mean  ...
# fuel_type_code_pudl                                                ...
# coal                 122.0  174.0  514.0      8547.0  2004.623143  ...
# gas                  134.0  177.0  513.0     11486.0  2005.978060  ...
# ...

# %%
fuel_cost = fuel_type_group['fuel_cost_per_unit_burned']

# %%
fuel_cost.describe()
# Out:
#                        count         mean           std     min      25%  \
# fuel_type_code_pudl
# coal                  8547.0    67.421830    943.771433    0.00  23.9585
# gas                  11486.0    13.659397    163.286631    0.00   3.2300
# nuclear                818.0  4955.157002  14291.929749    0.00   1.6015
# oil                   8064.0   168.877086   2406.101479    0.00  37.6100
# other                  167.0    18.253856     29.016882 -119.04   2.6325
# waste                  441.0    19.518122     29.988017 -276.08  10.3350
#
#                          50%       75%         max
# fuel_type_code_pudl
# coal                 33.3180  44.66800   44033.320
# gas                   4.6500   6.96000   10490.000
# nuclear              32.5200  50.85525   69785.215
# oil                  68.9455  98.68925  139358.000
# other                 9.0640  20.05500     134.547
# waste                21.9330  32.65000     132.291

# %% [markdown]
# ### Question 4

# %%
mmbtu_per_unit_group = data_set['fuel_mmbtu_per_unit']

# %%
mmbtu_per_unit_group.std()
# Out:
# 10.600220307806886

# %%
mmbtu_per_unit_group.describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %% [markdown]
# ### Question 5

# %%
fuel_qty = data_set['fuel_qty_burned']

# %%
kurt = fuel_qty.kurtosis()

# %%
kurt
# Out:
# 651.3694501337732

# %%
skew = fuel_qty.skew()

# %%
skew
# Out:
# 15.851495469109503

# %% [markdown]
# ### Question 6

# %%
data_set.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
frac = 180/29523
perc= 100 * frac

# %%
perc
# Out:
# 0.609694136774718

# %% [markdown]
# ### Question 7

# %%
data_set['fuel_unit'].describe
# Out:
# <bound method NDFrame.describe of 0        ton
# 1        ton
# 2        ton
# 3        ton
# 4        mcf
#         ...
# 29518    mcf
# 29519    mcf
# 29520    mcf
# 29521    ton
# 29522    mcf
# Name: fuel_unit, Length: 29523, dtype: object>

# %% [markdown]
# ### Question 8

# %%
fuel_cost_group = data_set.groupby('fuel_cost_per_unit_burned')

# %%
corr = fuel_cost_group.corr()

# %%
corr
# Out:
#                                                         utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.08                   utility_id_ferc1                           NaN
#                           report_year                                NaN
#                           fuel_qty_burned                            NaN
#                           fuel_mmbtu_per_unit                        NaN
#                           fuel_cost_per_unit_delivered               NaN
# ...                                                                  ...
#  139358.00                report_year                                NaN
#                           fuel_qty_burned                            NaN
#                           fuel_mmbtu_per_unit                        NaN
#                           fuel_cost_per_unit_delivered               NaN
#                           fuel_cost_per_mmbtu                        NaN
#
# ...

# %% [markdown]
# ### Question 9

# %%
try_group = data_set.groupby('fuel_type_code_pudl')['report_year']

# %%
try_group.describe()
# Out:
#                        count         mean       std     min      25%     50%  \
# fuel_type_code_pudl
# coal                  8547.0  2004.623143  7.137389  1994.0  1998.00  2004.0
# gas                  11486.0  2005.978060  7.280214  1994.0  1999.25  2006.0
# nuclear                818.0  2002.970660  7.155665  1994.0  1997.00  2001.0
# oil                   8064.0  2007.195933  6.140652  1994.0  2003.00  2007.0
# other                  167.0  2001.700599  5.712505  1994.0  1997.00  2000.0
# waste                  441.0  2005.650794  7.460231  1994.0  1998.00  2006.0
#
#                         75%     max
# fuel_type_code_pudl
# coal                 2011.0  2018.0
# gas                  2012.0  2018.0
# nuclear              2008.0  2018.0
# oil                  2012.0  2018.0
# other                2006.0  2016.0
# waste                2012.0  2018.0

# %% [markdown]
# ### Question 10

# %%
try_group2 = data_set.groupby('fuel_cost_per_unit_delivered')['report_year']

# %%
try_group2.describe()
# Out:
#                               count    mean  std     min     25%     50%  \
# fuel_cost_per_unit_delivered
# -874.937                        1.0  2008.0  NaN  2008.0  2008.0  2008.0
# -488.054                        1.0  2007.0  NaN  2007.0  2007.0  2007.0
# -313.410                        1.0  2004.0  NaN  2004.0  2004.0  2004.0
# -174.670                        3.0  2000.0  0.0  2000.0  2000.0  2000.0
# -170.187                        1.0  2015.0  NaN  2015.0  2015.0  2015.0
# ...                             ...     ...  ...     ...     ...     ...
#  1942979.000                    1.0  1997.0  NaN  1997.0  1997.0  1997.0
#  2114508.000                    1.0  1996.0  NaN  1996.0  1996.0  1996.0
#  2255688.000                    1.0  1997.0  NaN  1997.0  1997.0  1997.0
#  7793482.000                    1.0  1996.0  NaN  1996.0  1996.0  1996.0
#  7964521.000                    1.0  1997.0  NaN  1997.0  1997.0  1997.0
#
#                                  75%     max
# ...
